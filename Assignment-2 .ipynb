# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Loading dataset car_crashes

# %%
#importing and loading datasets
p=sns.load_dataset('car_crashes')
p
# Out:
#     total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 0    18.8     7.332    5.640          18.048       15.040       784.55
# 1    18.1     7.421    4.525          16.290       17.014      1053.48
# 2    18.6     6.510    5.208          15.624       17.856       899.47
# 3    22.4     4.032    5.824          21.056       21.280       827.34
# 4    12.0     4.200    3.360          10.920       10.680       878.41
# 5    13.6     5.032    3.808          10.744       12.920       835.50
# 6    10.8     4.968    3.888           9.396        8.856      1068.73
# 7    16.2     6.156    4.860          14.094       16.038      1137.87
# 8     5.9     2.006    1.593           5.900        5.900      1273.89
# 9    17.9     3.759    5.191          16.468       16.826      1160.13
# 10   15.6     2.964    3.900          14.820       14.508       913.15
# 11   17.5     9.450    7.175          14.350       15.225       861.18
# ...

# %% [markdown]
# # Finding dimensions of dataset car_crashes

# %%
p.shape
# Out:
# (51, 8)

# %% [markdown]
# Inference:From above code gives number of columns and rows present in dataset carcrashes.There are 51 row and 8 columns in dataset carcrashes

# %% [markdown]
# # Finding basic info of dataset car_crashes

# %%
p.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   total           51 non-null     float64
#  1   speeding        51 non-null     float64
#  2   alcohol         51 non-null     float64
#  3   not_distracted  51 non-null     float64
#  4   no_previous     51 non-null     float64
#  5   ins_premium     51 non-null     float64
#  6   ins_losses      51 non-null     float64
#  7   abbrev          51 non-null     object
# dtypes: float64(7), object(1)
# memory usage: 3.3+ KB

# %% [markdown]
# Inference : it shows number of rows and provides basic description of rows and columns

# %% [markdown]
# # it gives count, mean, standard deviation, minimum, and maximum values.

# %%
p.describe()
# Out:
#            total   speeding    alcohol  not_distracted  no_previous  \
# count  51.000000  51.000000  51.000000       51.000000    51.000000
# mean   15.790196   4.998196   4.886784       13.573176    14.004882
# std     4.122002   2.017747   1.729133        4.508977     3.764672
# min     5.900000   1.792000   1.593000        1.760000     5.900000
# 25%    12.750000   3.766500   3.894000       10.478000    11.348000
# 50%    15.600000   4.608000   4.554000       13.857000    13.775000
# 75%    18.500000   6.439000   5.604000       16.140000    16.755000
# max    23.900000   9.450000  10.038000       23.661000    21.280000
#
#        ins_premium  ins_losses
# count    51.000000   51.000000
# mean    886.957647  134.493137
# std     178.296285   24.835922
# min     641.960000   82.750000
# 25%     768.430000  114.645000
# 50%     858.970000  136.050000
# 75%    1007.945000  151.870000
# max    1301.520000  194.780000

# %% [markdown]
# Inference:It describes as percentile how many accidents took per quantile and also provides standard deviation, mean ,average

# %% [markdown]
# # gives first 5 data in dataset carcrashes

# %%
p.head()
# Out:
#    total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 0   18.8     7.332    5.640          18.048       15.040       784.55
# 1   18.1     7.421    4.525          16.290       17.014      1053.48
# 2   18.6     6.510    5.208          15.624       17.856       899.47
# 3   22.4     4.032    5.824          21.056       21.280       827.34
# 4   12.0     4.200    3.360          10.920       10.680       878.41
#
#    ins_losses abbrev
# 0      145.08     AL
# 1      133.93     AK
# 2      110.35     AZ
# 3      142.39     AR
# 4      165.63     CA

# %%
Inference:It gives first 5 cases from the dataset carcrashes

# %% [markdown]
# # gives last 5 data dataset carcrashes

# %%
p.tail()
# Out:
#     total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 46   12.7     2.413    3.429          11.049       11.176       768.95
# 47   10.6     4.452    3.498           8.692        9.116       890.03
# 48   23.8     8.092    6.664          23.086       20.706       992.61
# 49   13.8     4.968    4.554           5.382       11.592       670.31
# 50   17.4     7.308    5.568          14.094       15.660       791.14
#
#     ins_losses abbrev
# 46      153.72     VA
# 47      111.62     WA
# 48      152.56     WV
# 49      106.62     WI
# 50      122.04     WY

# %%
Inference:It gives last 5 cases from the dataset carcrashes

# %% [markdown]
# # Multivariate

# %% [markdown]
# # Exploratory Data Analysis on Car Crashes Dataset - Key Factors Affecting Total Crashes

# %%
fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(12, 8))

# Create barplots for each column
sns.barplot(data=p, x='speeding', y='total', ax=axes[0, 0])
axes[0, 0].set_title('Speeding vs Total')

sns.barplot(data=p, x='alcohol', y='total', ax=axes[0, 1])
axes[0, 1].set_title('Alcohol vs Total')

sns.barplot(data=p, x='not_distracted', y='total', ax=axes[1, 0])
axes[1, 0].set_title('Not Distracted vs Total')

sns.barplot(data=p, x='no_previous', y='total', ax=axes[1, 1])
axes[1, 1].set_title('No Previous vs Total')

# Adjust layout
plt.tight_layout()

# Show the plots
plt.show()

# %% [markdown]
# Inference:above 4 graphs relate accidents more alcohol intake causes more accidents,number of drivers who have records of previous accidents were increasing.Here due to being a tuple multiple attributes cannot be drawn in one single graph.Here we imported matplotlib.pyplot and used subplot function and got graphs of all dependent variables

# %%
sns.scatterplot(x="alcohol",y="not_distracted",data=p,color="red")
# Out:
# <Axes: xlabel='alcohol', ylabel='not_distracted'>

# %%
sns.scatterplot(x="ins_losses",y="ins_premium",data=p,color="green")
# Out:
# <Axes: xlabel='ins_losses', ylabel='ins_premium'>

# %%
sns.scatterplot(x='total',y='speeding',data=p)
# Out:
# <Axes: xlabel='total', ylabel='speeding'>

# %% [markdown]
# Inference: Above scatterplot describes as speed increases number of accidents were also increasing and on average accidents were causing at position between region of 4-6

# %% [markdown]
# # Pairplot

# %%
sns.pairplot(p)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 2
#       1 sns.pairplot(p)
# ----> 2 plt.show()
#
# NameError: name 'plt' is not defined

# %% [markdown]
# Inference:Gives basic representation of all graph tells relation on how they are realted to the deaths in car_crashes dataset

# %% [markdown]
# # Bivariate

# %% [markdown]
# # Lineplot

# %%
sns.lineplot(x='total',y='speeding',data=p)
# Out:
# <Axes: xlabel='total', ylabel='speeding'>

# %% [markdown]
# Infernce:On average speeding id directly proportional to car crashes but there were extremely high at middle than at end where total is 17.5 where speeding is greater than 9

# %% [markdown]
# Inference: From above lineplot and scatterplot concludes that speeding is more then total death increases which is directly propotional

# %%
#lineplot
a=sns.lineplot(x="speeding",y="alcohol",data=p,color="green")

# %% [markdown]
# inference is that when alcohol increases speed also increases
# #directly proportional

# %%
sns.lineplot(x="alcohol",y="not_distracted",data=p,color="red")
# Out:
# <Axes: xlabel='alcohol', ylabel='not_distracted'>

# %% [markdown]
# Inference: On average,there is less levels of distraction the levels of not getting distracted is higher

# %%
sns.lineplot(x="ins_premium",y="ins_losses",data=p,color="cyan")
# Out:
# <Axes: xlabel='ins_premium', ylabel='ins_losses'>

# %% [markdown]
# Inference: On average, Premium increases ideally losses decreases

# %% [markdown]
# # Countplot

# %%
sns.set_style("whitegrid")  
sns.countplot(x="total", data=p)
plt.show()

# %% [markdown]
# Inference is this gives the total count of car crashes

# %%
sns.set_style("whitegrid")  
sns.countplot(x="not_distracted", data=p)
plt.show()

# %% [markdown]
#  Inference is this gives the total count of not_distracted car crashes

# %%
sns.set_style("whitegrid")  
sns.countplot(x="alcohol", data=p)
plt.title("Count of Alcohol",fontsize=20)
plt.show()

# %% [markdown]
# Inference is the count of alcohol is constant

# %% [markdown]
# # Histogram

# %%
sns.histplot(p['ins_premium'], color='orange')
plt.xlabel('Insurance Premium')
plt.ylabel('Frequency')
plt.title('Histogram of Insurance Premium')
plt.show()

# %% [markdown]
# Inference is for premium of 800 it has high frequency

# %%
sns.histplot(p['alcohol'], color='blue')
plt.xlabel('Alcohol')
plt.ylabel('Frequency')
plt.title('Histogram of car crashes due to Alcohol')
plt.show()

# %% [markdown]
# Inference is for alcohol of 4 has highest frequency

# %%
sns.histplot(p['speeding'], color='red')
plt.xlabel('Speeding')
plt.ylabel('Frequency')
plt.title('Histogram of car crashes due to Overspeeding')
plt.show()

# %% [markdown]
# Inference is for speeding of 4-5 has highest frequency

# %% [markdown]
# # BarPlot

# %%
sns.barplot(y=p['total'],x=p['speeding'],data=p)
# Out:
# <Axes: xlabel='speeding', ylabel='total'>

# %%
sns.barplot(y=p['alcohol'],x=p['total'],data=p)
# Out:
# <Axes: xlabel='total', ylabel='alcohol'>

# %%
sns.barplot(y=p['ins_losses'],x=p['ins_premium'],data=p)
# Out:
# <Axes: xlabel='ins_premium', ylabel='ins_losses'>

# %% [markdown]
# # Finding correlation for every attribute

# %%
a=p.corr()
a
# Out:
# C:\Users\amarn\AppData\Local\Temp\ipykernel_11404\4238299828.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   a=p.corr()
#                    total  speeding   alcohol  not_distracted  no_previous  \
# total           1.000000  0.611548  0.852613        0.827560     0.956179
# speeding        0.611548  1.000000  0.669719        0.588010     0.571976
# alcohol         0.852613  0.669719  1.000000        0.732816     0.783520
# not_distracted  0.827560  0.588010  0.732816        1.000000     0.747307
# no_previous     0.956179  0.571976  0.783520        0.747307     1.000000
# ins_premium    -0.199702 -0.077675 -0.170612       -0.174856    -0.156895
# ins_losses     -0.036011 -0.065928 -0.112547       -0.075970    -0.006359
#
#                 ins_premium  ins_losses
# total             -0.199702   -0.036011
# ...

# %% [markdown]
# Inference: It gives data from the region of -1 to 1 where greater than 0 can be considered as positively correlated and less than 0 are considered as neagtively corelated.From above premium insurance and intial loses are independent variables so they were negatively correlated.Speeding and alcohol are high positively correlated and not_distracted attribute is positively correlated

# %% [markdown]
# # Data visualising using heatmap

# %%
sns.heatmap(a, annot=True, cmap="YlGnBu")
# Out:
# <Axes: >

# %% [markdown]
# Inference: In above heatmap blue indicates extreme values which are positively correlated and green represents negatively correlated.We can get carcrashes more precisely like higher the speeding there is a chance of more likely to have accident.It also tells alcohol intake and carcrashes are directly proportional .It also tells where values are drivers are not distracted but had carcrash,it also tells insurance premium are not involved ,similarily losses weren't involved in the similar way.In this extreme values can be seen in dark blue and minimal values are seen in light green
